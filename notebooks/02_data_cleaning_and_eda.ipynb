# %% [markdown]
# # Telco Customer Churn Prediction - Feature Engineering
#
# This notebook presents the second step in developing a machine learning model to predict customer churn for a telecommunications company. In the first notebook, I cleaned and merged the excel files provided in [IBM's sample datasets](https://accelerator.ca.analytics.ibm.com/bi/?perspective=authoring&pathRef=.public_folders%2FIBM%2BAccelerator%2BCatalog%2FContent%2FDAT00148&id=i9710CF25EF75468D95FFFC7D57D45204&objRef=i9710CF25EF75468D95FFFC7D57D45204&action=run&format=HTML&cmPropStr=%7B%22id%22%3A%22i9710CF25EF75468D95FFFC7D57D45204%22%2C%22type%22%3A%22reportView%22%2C%22defaultName%22%3A%22DAT00148%22%2C%22permissions%22%3A%5B%22execute%22%2C%22read%22%2C%22traverse%22%5D%7D) into a single CSV file containing a consolidated dataset.
#
# In this notebook, I will:
#
# - Examine missing values and handle them appropriately
#
# - Identify redundant and useful features
#
# - Analyze data types and transform features as needed
#
# - Explore data distributions and correlations
#
# - Transform heavily skewed features and inspect outliers
#
# The goal is to transform the raw data into a format suitable for machine learning models.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Loading and inspecting data

# %%
telco = pd.read_csv("../data/processed/telco_merged.csv", index_col=0)

print(f"Shape: {telco.shape}")
telco.head()
# Out:
# Shape: (7043, 56)
#              count  gender  age under_30 senior_citizen married dependents  \
# customer_id
# 0002-ORFBO       1  Female   37       No             No     Yes         No
# 0003-MKNFE       1    Male   46       No             No      No         No
# 0004-TLHLJ       1    Male   50       No             No      No         No
# 0011-IGKFF       1    Male   78       No            Yes     Yes         No
# 0013-EXCHZ       1  Female   75       No            Yes     Yes         No
#
#              number_of_dependents location_id        country       state  \
# customer_id
# 0002-ORFBO                      0  FUGQUJ6597  United States  California
# 0003-MKNFE                      0  SIZFEJ5344  United States  California
# 0004-TLHLJ                      0  RZDAXJ8786  United States  California
# 0011-IGKFF                      0  MGKGVM9555  United States  California
# 0013-EXCHZ                      0  FJLSME1564  United States  California
#
#                      city  zip_code                lat_long   latitude  \
# customer_id
# 0002-ORFBO   Frazier Park     93225  34.827662, -118.999073  34.827662
# 0003-MKNFE       Glendale     91206  34.162515, -118.203869  34.162515
# 0004-TLHLJ     Costa Mesa     92627  33.645672, -117.922613  33.645672
# 0011-IGKFF       Martinez     94553  38.014457, -122.115432  38.014457
# 0013-EXCHZ      Camarillo     93010  34.227846, -119.079903  34.227846
#
#               longitude     service_id quarter referred_a_friend  \
# customer_id
# 0002-ORFBO  -118.999073  MJBAXYDAX5462      Q3               Yes
# 0003-MKNFE  -118.203869  NICWXTOGG9486      Q3                No
# 0004-TLHLJ  -117.922613  DCSKWRXAI3251      Q3                No
# 0011-IGKFF  -122.115432  ZEOATALAE9483      Q3               Yes
# 0013-EXCHZ  -119.079903  MVMZRJAHU9423      Q3               Yes
#
#              number_of_referrals  tenure_in_months    offer phone_service  \
# customer_id
# 0002-ORFBO                     2                 9      NaN           Yes
# 0003-MKNFE                     0                 9      NaN           Yes
# 0004-TLHLJ                     0                 4  Offer E           Yes
# 0011-IGKFF                     1                13  Offer D           Yes
# 0013-EXCHZ                     3                 3      NaN           Yes
#
#              avg_monthly_long_distance_charges multiple_lines  \
# customer_id
# 0002-ORFBO                               42.39             No
# 0003-MKNFE                               10.69            Yes
# 0004-TLHLJ                               33.65             No
# 0011-IGKFF                               27.82             No
# 0013-EXCHZ                                7.38             No
#
#             internet_service internet_type  avg_monthly_gb_download  \
# customer_id
# 0002-ORFBO               Yes         Cable                       16
# 0003-MKNFE               Yes         Cable                       10
# 0004-TLHLJ               Yes   Fiber Optic                       30
# 0011-IGKFF               Yes   Fiber Optic                        4
# 0013-EXCHZ               Yes   Fiber Optic                       11
#
#             online_security online_backup device_protection_plan  \
# customer_id
# 0002-ORFBO               No           Yes                     No
# 0003-MKNFE               No            No                     No
# 0004-TLHLJ               No            No                    Yes
# 0011-IGKFF               No           Yes                    Yes
# 0013-EXCHZ               No            No                     No
#
#             premium_tech_support streaming_tv streaming_movies  \
# customer_id
# 0002-ORFBO                   Yes          Yes               No
# 0003-MKNFE                    No           No              Yes
# 0004-TLHLJ                    No           No               No
# 0011-IGKFF                    No          Yes              Yes
# 0013-EXCHZ                   Yes          Yes               No
#
#             streaming_music unlimited_data        contract paperless_billing  \
# customer_id
# 0002-ORFBO               No            Yes        One Year               Yes
# 0003-MKNFE              Yes             No  Month-to-Month                No
# 0004-TLHLJ               No            Yes  Month-to-Month               Yes
# 0011-IGKFF               No            Yes  Month-to-Month               Yes
# 0013-EXCHZ               No            Yes  Month-to-Month               Yes
#
#               payment_method  monthly_charge  total_charges  total_refunds  \
# customer_id
# 0002-ORFBO       Credit Card            65.6         593.30           0.00
# 0003-MKNFE       Credit Card            59.9         542.40          38.33
# 0004-TLHLJ   Bank Withdrawal            73.9         280.85           0.00
# 0011-IGKFF   Bank Withdrawal            98.0        1237.85           0.00
# 0013-EXCHZ       Credit Card            83.9         267.40           0.00
#
#              total_extra_data_charges  total_long_distance_charges  \
# customer_id
# 0002-ORFBO                          0                       381.51
# 0003-MKNFE                         10                        96.21
# 0004-TLHLJ                          0                       134.60
# 0011-IGKFF                          0                       361.66
# 0013-EXCHZ                          0                        22.14
#
#              total_revenue   status_id  satisfaction_score customer_status  \
# customer_id
# 0002-ORFBO          974.81  UAAWUJ8685                   3          Stayed
# 0003-MKNFE          610.28  URNYXG9268                   5          Stayed
# 0004-TLHLJ          415.45  LOOUCZ6174                   1         Churned
# 0011-IGKFF         1599.51  HDYLOW1467                   1         Churned
# 0013-EXCHZ          289.54  EICWUI5128                   1         Churned
#
#             churn_label  churn_value  churn_score  cltv   churn_category  \
# customer_id
# 0002-ORFBO           No            0           65  2205              NaN
# 0003-MKNFE           No            0           66  5414              NaN
# 0004-TLHLJ          Yes            1           71  4479       Competitor
# 0011-IGKFF          Yes            1           91  3714  Dissatisfaction
# 0013-EXCHZ          Yes            1           68  3464  Dissatisfaction
#
#                               churn_reason   id  population
# customer_id
# 0002-ORFBO                             NaN  661        4498
# 0003-MKNFE                             NaN  185       31297
# 0004-TLHLJ   Competitor had better devices  546       62069
# 0011-IGKFF         Product dissatisfaction  984       46677
# 0013-EXCHZ             Network reliability  618       42853

# %%
# Check if there are any duplicated rows
telco.duplicated().sum()
# Out:
# 0

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0002-ORFBO to 9995-HOTOH
# Data columns (total 56 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   count                              7043 non-null   int64
#  1   gender                             7043 non-null   object
#  2   age                                7043 non-null   int64
#  3   under_30                           7043 non-null   object
#  4   senior_citizen                     7043 non-null   object
#  5   married                            7043 non-null   object
#  6   dependents                         7043 non-null   object
#  7   number_of_dependents               7043 non-null   int64
#  8   location_id                        7043 non-null   object
#  9   country                            7043 non-null   object
#  10  state                              7043 non-null   object
#  11  city                               7043 non-null   object
#  12  zip_code                           7043 non-null   int64
#  13  lat_long                           7043 non-null   object
#  14  latitude                           7043 non-null   float64
#  15  longitude                          7043 non-null   float64
#  16  service_id                         7043 non-null   object
#  17  quarter                            7043 non-null   object
#  18  referred_a_friend                  7043 non-null   object
#  19  number_of_referrals                7043 non-null   int64
#  20  tenure_in_months                   7043 non-null   int64
#  21  offer                              3166 non-null   object
#  22  phone_service                      7043 non-null   object
#  23  avg_monthly_long_distance_charges  7043 non-null   float64
#  24  multiple_lines                     7043 non-null   object
#  25  internet_service                   7043 non-null   object
#  26  internet_type                      5517 non-null   object
#  27  avg_monthly_gb_download            7043 non-null   int64
#  28  online_security                    7043 non-null   object
#  29  online_backup                      7043 non-null   object
#  30  device_protection_plan             7043 non-null   object
#  31  premium_tech_support               7043 non-null   object
#  32  streaming_tv                       7043 non-null   object
#  33  streaming_movies                   7043 non-null   object
#  34  streaming_music                    7043 non-null   object
#  35  unlimited_data                     7043 non-null   object
#  36  contract                           7043 non-null   object
#  37  paperless_billing                  7043 non-null   object
#  38  payment_method                     7043 non-null   object
#  39  monthly_charge                     7043 non-null   float64
#  40  total_charges                      7043 non-null   float64
#  41  total_refunds                      7043 non-null   float64
#  42  total_extra_data_charges           7043 non-null   int64
#  43  total_long_distance_charges        7043 non-null   float64
#  44  total_revenue                      7043 non-null   float64
#  45  status_id                          7043 non-null   object
#  46  satisfaction_score                 7043 non-null   int64
#  47  customer_status                    7043 non-null   object
#  48  churn_label                        7043 non-null   object
#  49  churn_value                        7043 non-null   int64
#  50  churn_score                        7043 non-null   int64
#  51  cltv                               7043 non-null   int64
#  52  churn_category                     1869 non-null   object
#  53  churn_reason                       1869 non-null   object
#  54  id                                 7043 non-null   int64
#  55  population                         7043 non-null   int64
# dtypes: float64(8), int64(14), object(34)
# memory usage: 3.1+ MB

# %% [markdown]
# ## 2. Handling missing values

# %%
def missing_values(df):
    """Generate a dataframe containing info on missing values"""
    missing = df.isna().sum()
    missing_pct = round(100 * (missing / len(df)), 2)

    res = pd.DataFrame({
        'missing_count': missing.values,
        'missing_pct': missing_pct,
    })

    return res[res['missing_count'] > 0]

missing_values(telco).sort_values('missing_count', ascending=False)
# Out:
#                 missing_count  missing_pct
# churn_category           5174        73.46
# churn_reason             5174        73.46
# offer                    3877        55.05
# internet_type            1526        21.67

# %%
for col in ['offer', 'internet_type', 'churn_category', 'churn_reason']:
    print(f"Column: {col} ({telco[col].dtype})")
    print(f"Values: {telco[col].unique()}", end='\n\n')
# Out:
# Column: offer (object)
# Values: [nan 'Offer E' 'Offer D' 'Offer A' 'Offer B' 'Offer C']
#
# Column: internet_type (object)
# Values: ['Cable' 'Fiber Optic' 'DSL' nan]
#
# Column: churn_category (object)
# Values: [nan 'Competitor' 'Dissatisfaction' 'Other' 'Price' 'Attitude']
#
# Column: churn_reason (object)
# Values: [nan 'Competitor had better devices' 'Product dissatisfaction'
#  'Network reliability' 'Limited range of services'
#  'Competitor made better offer' "Don't know" 'Long distance charges'
#  'Attitude of service provider' 'Attitude of support person'
#  'Competitor offered higher download speeds'
#  'Competitor offered more data' 'Lack of affordable download/upload speed'
#  'Deceased' 'Moved' 'Service dissatisfaction' 'Price too high'
#  'Lack of self-service on Website' 'Poor expertise of online support'
#  'Extra data charges' 'Poor expertise of phone support']

# %% [markdown]
# ### Analyzing features with missing values
#
# 1. `offer` and `internet_type`: One optino here is to assign binary values reflecting the existence of an offer or an internet service. However, I'll choose to preserve more information by replacing null values by no_offer/no_internet entries as different internet or offer types hay have impact on customer churn.

# %%
telco['internet_type'] = telco['internet_type'].apply(lambda x: 'no_internet' if x is np.nan else x)

telco['internet_type'].value_counts()
# Out:
# internet_type
# Fiber Optic    3035
# DSL            1652
# no_internet    1526
# Cable           830
# Name: count, dtype: int64

# %%
telco['offer'] = telco['offer'].apply(lambda x: 'no_offer' if x is np.nan else x)

telco['offer'].value_counts()
# Out:
# offer
# no_offer    3877
# Offer B      824
# Offer E      805
# Offer D      602
# Offer A      520
# Offer C      415
# Name: count, dtype: int64

# %% [markdown]
# 2. `churn_category` and `churn_reason`: These attributes provide reasons for why a customer has left. This information could be helpful for a different analysis, but it would cause data leakage in prediction modeling, hence I'll drop these columns.

# %%
telco.drop(['churn_category', 'churn_reason'], axis=1, inplace=True)

# %% [markdown]
# Check the dataset after handling missing values:

# %%
print(f"Shape: {telco.shape}")
print(f"Missing value count: {telco.isna().sum().sum()}")
# Out:
# Shape: (7043, 54)
# Missing value count: 0

# %% [markdown]
# ## 3. Analyzing features based on redundancy and usefulness
#
# In this section, I'll identify features that will be transformed or dropped from the dataset.

# %%
# Get an overview of the features
for col in telco.columns:
    print(f"Column: {col} ({telco[col].dtype})")
    print(f"Values: {telco[col].unique()}", end='\n\n')
# Out:
# Column: count (int64)
# Values: [1]
#
# Column: gender (object)
# Values: ['Female' 'Male']
#
# Column: age (int64)
# Values: [37 46 50 78 75 23 67 52 68 43 47 25 58 32 39 72 79 26 30 22 34 42 64 48
#  28 33 31 60 69 20 57 19 38 54 35 51 66 61 24 55 59 71 49 40 21 45 29 62
#  76 77 73 41 56 80 63 53 44 70 74 36 27 65]
#
# Column: under_30 (object)
# Values: ['No' 'Yes']
#
# Column: senior_citizen (object)
# Values: ['No' 'Yes']
#
# Column: married (object)
# Values: ['Yes' 'No']
#
# Column: dependents (object)
# Values: ['No' 'Yes']
#
# Column: number_of_dependents (int64)
# Values: [0 3 1 2 4 6 5 9 7 8]
#
# Column: location_id (object)
# Values: ['FUGQUJ6597' 'SIZFEJ5344' 'RZDAXJ8786' ... 'WQKQWU2461' 'SIQQRR3964'
#  'CRAMQJ1493']
#
# Column: country (object)
# Values: ['United States']
#
# Column: state (object)
# Values: ['California']
#
# Column: city (object)
# Values: ['Frazier Park' 'Glendale' 'Costa Mesa' ... 'Jacumba' 'Carpinteria'
#  'Meadow Valley']
#
# Column: zip_code (int64)
# Values: [93225 91206 92627 ... 91934 93013 95956]
#
# Column: lat_long (object)
# Values: ['34.827662, -118.999073' '34.162515, -118.203869'
#  '33.645672, -117.922613' ... '32.787836, -117.232364'
#  '32.787836, -117.232375' '32.85723, -117.209775']
#
# Column: latitude (float64)
# Values: [34.827662 34.162515 33.645672 ... 32.649787 34.441398 39.937017]
#
# Column: longitude (float64)
# Values: [-118.999073 -118.203869 -117.922613 ... -116.2237   -119.513163
#  -121.058043]
#
# Column: service_id (object)
# Values: ['MJBAXYDAX5462' 'NICWXTOGG9486' 'DCSKWRXAI3251' ... 'OIUREITZZ3281'
#  'FCSUVGJPH6766' 'XAYFGNILM3246']
#
# Column: quarter (object)
# Values: ['Q3']
#
# Column: referred_a_friend (object)
# Values: ['Yes' 'No']
#
# Column: number_of_referrals (int64)
# Values: [ 2  0  1  3  8  9 10  5  4  7  6 11]
#
# Column: tenure_in_months (int64)
# Values: [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42]
#
# Column: offer (object)
# Values: ['no_offer' 'Offer E' 'Offer D' 'Offer A' 'Offer B' 'Offer C']
#
# Column: phone_service (object)
# Values: ['Yes' 'No']
#
# Column: avg_monthly_long_distance_charges (float64)
# Values: [42.39 10.69 33.65 ... 10.04 25.59  2.01]
#
# Column: multiple_lines (object)
# Values: ['No' 'Yes']
#
# Column: internet_service (object)
# Values: ['Yes' 'No']
#
# Column: internet_type (object)
# Values: ['Cable' 'Fiber Optic' 'DSL' 'no_internet']
#
# Column: avg_monthly_gb_download (int64)
# Values: [16 10 30  4 11 73 14  7 21 59 19 12 20 22 17  9  0 52 57 51 41 23 27  2
#  69 53 15 29 85 28 18 48 25 26  8  6  5 13 75 82 24 76 47 71 58 42  3 56
#  46 39]
#
# Column: online_security (object)
# Values: ['No' 'Yes']
#
# Column: online_backup (object)
# Values: ['Yes' 'No']
#
# Column: device_protection_plan (object)
# Values: ['No' 'Yes']
#
# Column: premium_tech_support (object)
# Values: ['Yes' 'No']
#
# Column: streaming_tv (object)
# Values: ['Yes' 'No']
#
# Column: streaming_movies (object)
# Values: ['No' 'Yes']
#
# Column: streaming_music (object)
# Values: ['No' 'Yes']
#
# Column: unlimited_data (object)
# Values: ['Yes' 'No']
#
# Column: contract (object)
# Values: ['One Year' 'Month-to-Month' 'Two Year']
#
# Column: paperless_billing (object)
# Values: ['Yes' 'No']
#
# Column: payment_method (object)
# Values: ['Credit Card' 'Bank Withdrawal' 'Mailed Check']
#
# Column: monthly_charge (float64)
# Values: [65.6  59.9  73.9  ... 91.75 68.8  67.85]
#
# Column: total_charges (float64)
# Values: [ 593.3   542.4   280.85 ...  742.9  4627.65 3707.6 ]
#
# Column: total_refunds (float64)
# Values: [ 0.   38.33 21.25 30.53 44.42 44.9  12.26  6.11 10.23 13.03 36.02 17.91
#   1.01 16.99 25.24 27.01  9.73 44.53 38.46 16.56  4.73 18.88  8.13  8.74
#  11.37  1.31 33.8  49.76 16.97 14.21 16.73 49.02  2.28  9.35 41.74 13.01
#  27.38 23.97 14.23 18.55  1.48  5.15 33.25 41.33 33.43 22.96 11.45 17.17
#  24.99 26.37 38.42 11.72 29.21 45.75 47.79 29.   15.76 17.6  15.17 14.57
#  26.32 25.62 20.45 37.06 43.66 28.7  22.34 49.79 46.66  6.26 38.37 49.24
#   3.55  7.3  16.96  3.85 34.83 23.39 23.72 33.13 43.76 26.02 40.62 48.54
#  10.76 35.34 14.15 12.81 24.07 45.61 16.89  4.18 33.67 17.96 26.99 20.17
#  21.81 47.04 12.55 32.65 34.44 36.61 45.44  6.79 48.25 41.66 18.62 20.29
#  11.05 15.41 49.37 45.07 36.29 33.24 29.17 29.64  6.65  4.7  33.1  31.05
#  42.57 45.38 25.79 11.8  34.67 36.04 39.68 16.38 36.92 24.08  5.83 45.81
#  49.06 12.66 41.23 30.14 46.06  3.34 19.31 44.13 35.28 44.17 37.45  3.33
#  31.58  2.62 36.66 38.84 17.14 12.48 38.65 11.83 22.55 16.27  8.88 18.85
#  46.99 44.63  1.69  8.96 49.38 24.98 17.76 23.16 16.91 33.73  2.93 48.59
#  37.37 12.07 31.9  12.59 44.81 26.7  28.63 21.08 13.37  1.09 23.13 37.03
#  40.95 25.57 44.51  2.18  9.49 49.57 14.3  15.57 17.3   8.35 27.15 37.49
#  41.18  9.48 28.98 16.85 21.35 13.07 48.95 17.19 46.75 21.52 37.68  5.44
#  23.89 37.01 36.6  11.85 18.21  5.49 42.18 38.09 28.49  4.25 19.5  28.35
#  37.55 47.19 46.67 18.17 17.01 27.6   9.22 18.78  9.68 10.28 43.68 44.16
#   3.51 29.76 21.58 39.99 15.24  5.9  16.86 13.43 47.36  6.72 15.2  24.92
#  15.73  5.73  3.2   4.93 40.64 27.24 46.07 24.36 19.32 29.88 36.52 17.16
#  38.15 19.67 29.5  17.03 29.29 10.47 45.6  35.44 29.41  8.3  29.93 20.28
#  28.09 37.04 45.82 43.25 37.44 40.54 46.39 39.45 18.64 27.09  1.83 47.91
#  48.79  7.43  5.55  7.39 14.24 47.45 32.71 28.93 15.43 14.67 39.27 25.67
#  25.49 24.44  2.76 19.16  2.24 38.61 29.11 25.98 43.31 21.9  46.78 20.23
#  36.4  47.59 41.85 38.57 27.89 29.95 44.31 26.83 45.47 14.78  6.41  4.48
#  25.84 19.25 36.07 20.16 14.22  9.99 34.69 37.64 45.37 22.97 22.4  15.02
#  36.13 32.55 43.95 47.73 39.93 23.79 11.    1.99  4.68  2.81 15.31 35.23
#   5.47 40.79 25.07 48.23  3.26  4.6   1.66 18.89 40.   36.38 35.01 30.75
#  29.84 45.54 30.45 25.42 49.22 47.87 42.64 39.92  9.39  5.01 43.96 49.53
#  12.19 49.51 45.69 41.67 27.3  42.34 35.7   8.53 36.44 21.71 38.98 46.64
#  34.59 19.63 14.93  3.59 23.01 40.41 49.23 40.46 21.72 23.28 28.42 22.53
#  35.05 43.38 29.59 32.59 30.26 33.07 28.83 42.29 30.46  8.5  46.26 18.72
#  21.53 25.55 26.87 21.6  17.33 10.7   4.08 41.2  47.2  33.29 17.88 30.22
#  34.29 34.16 26.84 35.61 18.39 47.02 10.65 42.89 20.87 41.21 16.12 43.12
#  32.46 12.16 22.72 44.86 16.26 19.89 29.32 44.58 36.78 35.82 32.53 38.34
#  28.08 23.33 14.49 23.67  2.97 23.47 24.9  48.61 14.76  2.21 27.79 48.09
#  26.55 21.32 15.38 34.47 38.48  4.76  1.27 17.05 19.12 23.92 34.09  9.79
#  39.15 29.99 33.21  2.29 32.09 48.66 21.69 11.48 46.81  4.96 18.84 42.43
#  16.58 10.17 48.26  1.65 23.61  9.34 17.5  12.8  32.24 34.45 15.62 39.18
#  40.15 39.29 36.22 21.17 25.92 47.55 33.76 23.5  10.57 20.19 44.   46.56
#  45.46  6.49 19.13 26.98 31.39 16.36  9.36 10.2 ]
#
# Column: total_extra_data_charges (int64)
# Values: [  0  10  20  40 120 100 130 110  60 140  50  80 150  70  30  90]
#
# Column: total_long_distance_charges (float64)
# Values: [381.51  96.21 134.6  ... 356.4   37.24 142.04]
#
# Column: total_revenue (float64)
# Values: [ 974.81  610.28  415.45 ...  129.99 4769.69 3707.6 ]
#
# Column: status_id (object)
# Values: ['UAAWUJ8685' 'URNYXG9268' 'LOOUCZ6174' ... 'UFWMVH7729' 'FJBUFN1164'
#  'UKMXFW1552']
#
# Column: satisfaction_score (int64)
# Values: [3 5 1 4 2]
#
# Column: customer_status (object)
# Values: ['Stayed' 'Churned' 'Joined']
#
# Column: churn_label (object)
# Values: ['No' 'Yes']
#
# Column: churn_value (int64)
# Values: [0 1]
#
# Column: churn_score (int64)
# Values: [65 66 71 91 68 55 26 49 34 25 54 52 57 53 37 50 92 85 61 75 78 59 81 74
#  60 76 20 42 72 29 46 95 73 36 67 43 93 48 39 30 62 33 89 80 40 45 94 90
#  63 77 82 87 69 64 79 84 32 44 21 86 51 23 70 83 41 47 27 28 35 38 58 96
#  24 88 56 31 22  8  7  9  5]
#
# Column: cltv (int64)
# Values: [2205 5414 4479 ... 3245 5773 5639]
#
# Column: id (int64)
# Values: [ 661  185  546 ...  303  620 1530]
#
# Column: population (int64)
# Values: [ 4498 31297 62069 ... 13027 33038 17409]

# %% [markdown]
# ### 3.1 `internet_service`
#
# I'll drop this feature as cleaning and keeping `internet_type` in the last section makes it redundant. Just to make sure the data is non-problematic here, I'll first check whether `internet_service` coresponds to no_internet in `internet_type`.

# %%
# Check whether both columns correspond perfectly
((telco['internet_service'] == 'No') == (telco['internet_type'] == 'no_internet')).all()
# Out:
# True

# %%
telco.drop(['internet_service'], axis=1, inplace=True)

# %% [markdown]
# ### 3.2 `dependents`
#
# Since there is already a `number_of_dependents` feature, I'll drop this column after checking whether the two columns correspond perfectly.

# %%
((telco['dependents'] == 'No') == (telco['number_of_dependents'] == 0)).all()
# Out:
# True

# %%
telco.drop(['dependents'], axis=1, inplace=True)

# %% [markdown]
# ### 3.3 `referred_a_friend`
#
# Since there is already a `number_of_referrals` feature, I'll drop this column after checking data integrity.

# %%
((telco['referred_a_friend'] == 'No') == (telco['number_of_referrals'] == 0)).all()
# Out:
# True

# %%
telco.drop(['referred_a_friend'], axis=1, inplace=True)

# %% [markdown]
# ### 3.4 Features with no variance, and identifier features
#
# There are some features in the dataset that contain the same single value for all customers, and at the other extreme, some that are unique for each customer. I'll drop both cases as they are not useful for prediction.
#
# Additionally, the `id` column is a remnant of the population excel file (see previous notebook) which identifies zip codes, and is not useful for my analysis.

# %%
def cardinality(df, max_display=3):
    res = pd.DataFrame({
        'nunique': df.nunique(),
        'dtype': df.dtypes
    }).sort_values(by='nunique')

    res['unique_values'] = [
        df[col].unique().tolist() if res.loc[col, 'nunique'] <= max_display
        else f"[{', '.join(map(str, df[col].unique()[:max_display]))} ...(cont'd)]"
        for col in res.index
    ]

    return res

cardinality(telco)
# Out:
#                                    nunique    dtype  \
# count                                    1    int64
# country                                  1   object
# state                                    1   object
# quarter                                  1   object
# churn_value                              2    int64
# churn_label                              2   object
# paperless_billing                        2   object
# unlimited_data                           2   object
# streaming_music                          2   object
# streaming_movies                         2   object
# streaming_tv                             2   object
# premium_tech_support                     2   object
# device_protection_plan                   2   object
# online_backup                            2   object
# multiple_lines                           2   object
# phone_service                            2   object
# online_security                          2   object
# gender                                   2   object
# under_30                                 2   object
# senior_citizen                           2   object
# married                                  2   object
# contract                                 3   object
# customer_status                          3   object
# payment_method                           3   object
# internet_type                            4   object
# satisfaction_score                       5    int64
# offer                                    6   object
# number_of_dependents                    10    int64
# number_of_referrals                     12    int64
# total_extra_data_charges                16    int64
# avg_monthly_gb_download                 50    int64
# age                                     62    int64
# tenure_in_months                        72    int64
# churn_score                             81    int64
# total_refunds                          500  float64
# city                                  1106   object
# population                            1569    int64
# monthly_charge                        1585  float64
# longitude                             1625  float64
# id                                    1625    int64
# zip_code                              1625    int64
# latitude                              1626  float64
# lat_long                              1679   object
# cltv                                  3438    int64
# avg_monthly_long_distance_charges     3584  float64
# total_long_distance_charges           6087  float64
# total_charges                         6540  float64
# total_revenue                         6982  float64
# service_id                            7043   object
# status_id                             7043   object
# location_id                           7043   object
#
#                                                                        unique_values
# count                                                                            [1]
# country                                                              [United States]
# state                                                                   [California]
# quarter                                                                         [Q3]
# churn_value                                                                   [0, 1]
# churn_label                                                                [No, Yes]
# paperless_billing                                                          [Yes, No]
# unlimited_data                                                             [Yes, No]
# streaming_music                                                            [No, Yes]
# streaming_movies                                                           [No, Yes]
# streaming_tv                                                               [Yes, No]
# premium_tech_support                                                       [Yes, No]
# device_protection_plan                                                     [No, Yes]
# online_backup                                                              [Yes, No]
# multiple_lines                                                             [No, Yes]
# phone_service                                                              [Yes, No]
# online_security                                                            [No, Yes]
# gender                                                                [Female, Male]
# under_30                                                                   [No, Yes]
# senior_citizen                                                             [No, Yes]
# married                                                                    [Yes, No]
# contract                                        [One Year, Month-to-Month, Two Year]
# customer_status                                            [Stayed, Churned, Joined]
# payment_method                          [Credit Card, Bank Withdrawal, Mailed Check]
# internet_type                                  [Cable, Fiber Optic, DSL ...(cont'd)]
# satisfaction_score                                             [3, 5, 1 ...(cont'd)]
# offer                                       [no_offer, Offer E, Offer D ...(cont'd)]
# number_of_dependents                                           [0, 3, 1 ...(cont'd)]
# number_of_referrals                                            [2, 0, 1 ...(cont'd)]
# total_extra_data_charges                                     [0, 10, 20 ...(cont'd)]
# avg_monthly_gb_download                                     [16, 10, 30 ...(cont'd)]
# age                                                         [37, 46, 50 ...(cont'd)]
# tenure_in_months                                              [9, 4, 13 ...(cont'd)]
# churn_score                                                 [65, 66, 71 ...(cont'd)]
# total_refunds                                        [0.0, 38.33, 21.25 ...(cont'd)]
# city                                [Frazier Park, Glendale, Costa Mesa ...(cont'd)]
# population                                          [4498, 31297, 62069 ...(cont'd)]
# monthly_charge                                        [65.6, 59.9, 73.9 ...(cont'd)]
# longitude                          [-118.999073, -118.203869, -117.922613 ...(con...
# id                                                       [661, 185, 546 ...(cont'd)]
# zip_code                                           [93225, 91206, 92627 ...(cont'd)]
# latitude                               [34.827662, 34.162515, 33.645672 ...(cont'd)]
# lat_long                           [34.827662, -118.999073, 34.162515, -118.20386...
# cltv                                                  [2205, 5414, 4479 ...(cont'd)]
# avg_monthly_long_distance_charges                  [42.39, 10.69, 33.65 ...(cont'd)]
# total_long_distance_charges                       [381.51, 96.21, 134.6 ...(cont'd)]
# total_charges                                     [593.3, 542.4, 280.85 ...(cont'd)]
# total_revenue                        [974.81, 610.28, 415.4500000000001 ...(cont'd)]
# service_id                         [MJBAXYDAX5462, NICWXTOGG9486, DCSKWRXAI3251 ....
# status_id                           [UAAWUJ8685, URNYXG9268, LOOUCZ6174 ...(cont'd)]
# location_id                         [FUGQUJ6597, SIZFEJ5344, RZDAXJ8786 ...(cont'd)]

# %%
cols_to_drop = ['count', 'country', 'state', 'quarter', 'id', 'location_id', 'status_id', 'service_id']

telco.drop(cols_to_drop, axis=1, inplace=True)

# %% [markdown]
# ### 3.5 Location features
#
# Location related columns such as `city`, `zip_code` and `population` (which gives the population of the zip code, see the first notebook for details) are nominal features with high cardinality. One-hot encoding these features would create extremely sparse features, potentially leading to overfitting and computational complexity.
#
# Similarly, the continuous features `latitude`, `longitude` and `lat_long` could provide valuable distance and approximity information, but for simplicity, I'll remove these features and focus on more directly interpretable variables.

# %%
telco.drop(['latitude', 'longitude', 'lat_long', 'city', 'zip_code', 'population'], axis=1, inplace=True)

# %% [markdown]
# ### 3.6 Age related features
#
# There are multiple age-related features: The numeric `age` column, and the binary `under_30` and `senior_citizen` columns.

# %%
# Visualize age distribution
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(telco['age'], kde=True, bins=30)
plt.title('Age Distribution')
plt.axvline(x=30, color='r', linestyle='--', label='Under 30 Threshold')
plt.axvline(x=65, color='g', linestyle='--', label='Senior Threshold')
plt.legend()

plt.subplot(1, 2, 2)
age_churn = pd.DataFrame({
    'age': telco['age'],
    'churn': telco['churn_value']
})
sns.boxplot(x='churn', y='age', data=age_churn)
plt.title('Age Distribution by Churn Status')
plt.xlabel('Churned (1) vs Not Churned (0)')

plt.tight_layout()
plt.show()

# %% [markdown]
# I'll only keep `age` to preserve more information while avoiding repetition. It's revisit experimenting with age groups during modeling.

# %%
telco.drop(['under_30', 'senior_citizen'], axis=1, inplace=True)

# %% [markdown]
# ### 3.7 Handling the target variable
#
# There are four remaining features in the dataset that provide info on the churn of customers: `churn_label`, `churn_value`, `churn_score`, `customer_status`

# %%
# Inspect churn related features that remain:
for col in ['churn_label', 'churn_value', 'churn_score', 'customer_status']:
    print(f"Column: {col} ({telco[col].dtype})")
    print(f"Values: {telco[col].unique()}", end='\n\n')
# Out:
# Column: churn_label (object)
# Values: ['No' 'Yes']
#
# Column: churn_value (int64)
# Values: [0 1]
#
# Column: churn_score (int64)
# Values: [65 66 71 91 68 55 26 49 34 25 54 52 57 53 37 50 92 85 61 75 78 59 81 74
#  60 76 20 42 72 29 46 95 73 36 67 43 93 48 39 30 62 33 89 80 40 45 94 90
#  63 77 82 87 69 64 79 84 32 44 21 86 51 23 70 83 41 47 27 28 35 38 58 96
#  24 88 56 31 22  8  7  9  5]
#
# Column: customer_status (object)
# Values: ['Stayed' 'Churned' 'Joined']

# %%
# Check whether churn_value and churn_label correspond perfectly
((telco['churn_value'] == 'Yes') == (telco['churn_label'] == 1)).all()
# Out:
# True

# %%
# Check whether churn_value and customer_status correspond perfectly on churns
((telco['churn_value'] == 1) == (telco['customer_status'] == 'Churned')).all()
# Out:
# True

# %% [markdown]
# Observations:
#
# - `churn_score` seems to be a probability or score reflecting churn risk.
#
# - `customer_status` provides not only churn info, but also for newly joined customers
#
# For my modeling task, I'll use binary data for churn, therefore `churn_value` is a good option for the target feature. I'll drop the others to avoid data leakage.

# %%
telco.drop(['churn_label', 'churn_score', 'customer_status'], axis=1, inplace=True)

# %% [markdown]
# ### 3.8 Handling binary features
#
# Among the binary features in my dataset, most provide informtion in the format of true-false. Here I'll encode them manually to make sure true corresponds to 1, to ensure consistency and interpretability. One exception is `gender` (male/female); since 1 does not correspond to either, I'll leave this to one-hot encoding.

# %%
cardinality(telco)[cardinality(telco)['nunique'] == 2]
# Out:
#                         nunique   dtype   unique_values
# gender                        2  object  [Female, Male]
# paperless_billing             2  object       [Yes, No]
# unlimited_data                2  object       [Yes, No]
# streaming_music               2  object       [No, Yes]
# streaming_movies              2  object       [No, Yes]
# streaming_tv                  2  object       [Yes, No]
# churn_value                   2   int64          [0, 1]
# device_protection_plan        2  object       [No, Yes]
# online_backup                 2  object       [Yes, No]
# online_security               2  object       [No, Yes]
# premium_tech_support          2  object       [Yes, No]
# multiple_lines                2  object       [No, Yes]
# phone_service                 2  object       [Yes, No]
# married                       2  object       [Yes, No]

# %%
binary_features = cardinality(telco)[cardinality(telco)['nunique'] == 2].index.to_list()
cols_to_encode = [c for c in binary_features if c not in ['gender', 'churn_value']]

for col in cols_to_encode:
    telco[col] = telco[col].apply(lambda x: 1 if x == 'Yes' else 0)

cardinality(telco)[cardinality(telco)['nunique'] == 2]
# Out:
#                         nunique   dtype   unique_values
# gender                        2  object  [Female, Male]
# paperless_billing             2   int64          [1, 0]
# unlimited_data                2   int64          [1, 0]
# streaming_music               2   int64          [0, 1]
# streaming_movies              2   int64          [0, 1]
# streaming_tv                  2   int64          [1, 0]
# churn_value                   2   int64          [0, 1]
# device_protection_plan        2   int64          [0, 1]
# online_backup                 2   int64          [1, 0]
# online_security               2   int64          [0, 1]
# premium_tech_support          2   int64          [1, 0]
# multiple_lines                2   int64          [0, 1]
# phone_service                 2   int64          [1, 0]
# married                       2   int64          [1, 0]

# %% [markdown]
# ## 4. Correlations

# %%
# Correlation matrix for numerical features
plt.figure(figsize=(20, 20))
correlation = telco.corr(numeric_only=True)
mask = np.triu(np.ones_like(correlation, dtype=bool))
sns.heatmap(correlation, mask=mask, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=telco, x='total_charges', y='total_revenue')
plt.show()

# %% [markdown]
# The correlation between `total_charges` and `total_revenue` is too strong, so I'll drop one of them.

# %%
telco.drop(['total_charges'], axis=1, inplace=True)

# %% [markdown]
# There are two pairs of variables that have a high correlation: `tenure_in_months`-`total_revenue` and `streaming_movies`-`streaming_music`.

# %%
sns.scatterplot(data=telco, x='tenure_in_months', y='total_revenue')
plt.show()

# %% [markdown]
# I won't modify the first pair as they are crucial information about the churn risk of a customer. However, whether a customer uses streaming is more important than the distinction between movies and music in this context, so I'll replace the second pair with a new `streaming` feature after chceking how much they correspond.

# %%
# Check the correspondence
(telco['streaming_movies'] == telco['streaming_music']).value_counts(normalize=True)
# Out:
# True     0.928156
# False    0.071844
# Name: proportion, dtype: float64

# %%
# Create new streaming feature
telco['streaming'] = telco['streaming_movies'] * telco['streaming_music']

# Remove the previous columns
telco.drop(['streaming_movies', 'streaming_music'], axis=1, inplace=True)

# %% [markdown]
# Also, note that `satisfaction_score` has a significant correlation with churn.

# %% [markdown]
# ## 5. Exploring data distributions
#
# Here is the current version of the dataset:

# %%
print(f"Shape: {telco.shape}")
card = cardinality(telco)
card
# Out:
# Shape: (7043, 30)
#                                    nunique    dtype  \
# gender                                   2   object
# churn_value                              2    int64
# paperless_billing                        2    int64
# unlimited_data                           2    int64
# streaming_tv                             2    int64
# premium_tech_support                     2    int64
# online_backup                            2    int64
# online_security                          2    int64
# multiple_lines                           2    int64
# device_protection_plan                   2    int64
# married                                  2    int64
# phone_service                            2    int64
# streaming                                2    int64
# payment_method                           3   object
# contract                                 3   object
# internet_type                            4   object
# satisfaction_score                       5    int64
# offer                                    6   object
# number_of_dependents                    10    int64
# number_of_referrals                     12    int64
# total_extra_data_charges                16    int64
# avg_monthly_gb_download                 50    int64
# age                                     62    int64
# tenure_in_months                        72    int64
# total_refunds                          500  float64
# monthly_charge                        1585  float64
# cltv                                  3438    int64
# avg_monthly_long_distance_charges     3584  float64
# total_long_distance_charges           6087  float64
# total_revenue                         6982  float64
#
#                                                                      unique_values
# gender                                                              [Female, Male]
# churn_value                                                                 [0, 1]
# paperless_billing                                                           [1, 0]
# unlimited_data                                                              [1, 0]
# streaming_tv                                                                [1, 0]
# premium_tech_support                                                        [1, 0]
# online_backup                                                               [1, 0]
# online_security                                                             [0, 1]
# multiple_lines                                                              [0, 1]
# device_protection_plan                                                      [0, 1]
# married                                                                     [1, 0]
# phone_service                                                               [1, 0]
# streaming                                                                   [0, 1]
# payment_method                        [Credit Card, Bank Withdrawal, Mailed Check]
# contract                                      [One Year, Month-to-Month, Two Year]
# internet_type                                [Cable, Fiber Optic, DSL ...(cont'd)]
# satisfaction_score                                           [3, 5, 1 ...(cont'd)]
# offer                                     [no_offer, Offer E, Offer D ...(cont'd)]
# number_of_dependents                                         [0, 3, 1 ...(cont'd)]
# number_of_referrals                                          [2, 0, 1 ...(cont'd)]
# total_extra_data_charges                                   [0, 10, 20 ...(cont'd)]
# avg_monthly_gb_download                                   [16, 10, 30 ...(cont'd)]
# age                                                       [37, 46, 50 ...(cont'd)]
# tenure_in_months                                            [9, 4, 13 ...(cont'd)]
# total_refunds                                      [0.0, 38.33, 21.25 ...(cont'd)]
# monthly_charge                                      [65.6, 59.9, 73.9 ...(cont'd)]
# cltv                                                [2205, 5414, 4479 ...(cont'd)]
# avg_monthly_long_distance_charges                [42.39, 10.69, 33.65 ...(cont'd)]
# total_long_distance_charges                     [381.51, 96.21, 134.6 ...(cont'd)]
# total_revenue                      [974.81, 610.28, 415.4500000000001 ...(cont'd)]

# %% [markdown]
# Let's start by visualizing the target variable.

# %%
print(f"Percentage distribution of the target")
print(telco['churn_value'].value_counts(normalize=True))

plt.figure(figsize=(6, 6))
s = sns.countplot(data=telco, y='churn_value')
plt.bar_label(s.containers[0], label_type='center')
plt.title("Churn distribution")
plt.show()
# Out:
# Percentage distribution of the target
# churn_value
# 0    0.73463
# 1    0.26537
# Name: proportion, dtype: float64

# %% [markdown]
# The target variable is imbalanced; I'll explore options to handle this during modeling stage.
#
# In order to visualize the distribution of features effectively, I'll group them according to the cardinality of their values set.

# %%
# Features to visualize pie charts and count plots
class_cols = card[card['nunique'] <= 12].index.to_list()
class_cols.remove('churn_value')

# %%
fig, axes = plt.subplots(len(class_cols), 3, figsize=(20, len(class_cols) * 3))

for i, col in enumerate(class_cols):
    cat_order = sorted(telco[col].unique())
    
    # Distribution of col
    sns.countplot(data=telco, x=col, ax=axes[i, 0], palette='Dark2', order=cat_order)
    axes[i, 0].set_title(f"Distribution of {col}")
    axes[i, 0].set_xlabel('')
    axes[i, 0].set_ylabel('Count')

    # Distribution of col by churn
    sns.countplot(data=telco, x=col, hue='churn_value', ax=axes[i, 1], order=cat_order)
    axes[i, 1].legend(title='Churn', loc='upper right')
    axes[i, 1].set_title(f"{col} by churn")
    axes[i, 1].set_xlabel('')
    axes[i, 1].set_ylabel('Count')

    # Percentage of churners within each value of col
    churn_by_cat = telco.groupby(col)['churn_value'].mean() * 100
    sns.barplot(x=churn_by_cat.index, y=churn_by_cat.values, ax=axes[i, 2], palette='Dark2', order=cat_order)
    axes[i, 2].set_title(f"Churn rate by {col}")
    axes[i, 2].set_xlabel('')
    axes[i, 2].set_ylabel('Percentage')
    axes[i, 2].set_ylim(0, churn_by_cat.max() * 1.1)
    
    for p in axes[i, 2].patches:
        axes[i, 2].annotate(f"{p.get_height():.1f}%",
                            (p.get_x() + p.get_width() / 2, p.get_height()),
                            ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# Some observations:
#
# - `contract`: The most dramatic observation is that people who have month-on-month contracts are way more likely to churn compared to othe types of contracts which makes sense as these customers choose not to commit to long-term plans
#
# - `payment_method`: People that use bank withdarawal or mailed check for their payment method are more likely to churn than credit users
#
# - `internet_type`: People that use fiber optic are more likely to churn compared to other internet types, with people with no internet having the lowest churn rates by far
#
# - `offer`: Among the offer types, Offer E stands out as the only option where people are more likely to churn than not, so this offer type seems escpacially dissatisfactory for customers
#
# - `number_of_dependents`, `number_of_referrals`: People who don't have dependents, and people who have a single referral seem more likely to churn compared to other number of referrals
#
# *Note that people with 4 or more dependents are quite few (barely visible in the count plots), so the churn percentages don't give much information in this range.*

# %%
# Find the number of people with 4 or more dependents
(telco['number_of_dependents'] >= 4).sum()
# Out:
# 26

# %% [markdown]
# More observations:
#
# - People who have `paperless_billing`, `unlimited_date`, `streaming_tv`, `streaming_movies` and `premium_tech_support` seem more likely to churn
#
# - People who are not `married` seem more likely to churn
#
# - `gender`: Males and females seem equally likely to churn, and the number of males and females seem roughly equal in the dataset
#
# One observation that raises questions:
#
# - `satisfaction_score`: It seems that people with scores less than 3 always churn, and people with scores higher than 3 never do. This is too perfect, let's investigate further:

# %%
telco[telco['satisfaction_score'] < 3]['churn_value'].value_counts()
# Out:
# churn_value
# 1    1440
# Name: count, dtype: int64

# %%
telco[telco['satisfaction_score'] > 3]['churn_value'].value_counts()
# Out:
# churn_value
# 0    2938
# Name: count, dtype: int64

# %% [markdown]
# This does not look good; `satisfaction_score` provides churn outcome information perfectly for around 4400 data points! It may be that these scores were collected after the customer's decision to leave or extend contract, but in any case, this feature indicates data leakage and I'll remove it from the dataset.

# %%
telco.drop(['satisfaction_score'], axis=1, inplace=True)

# %% [markdown]
# Let's continue with the visualization of the rest of the variables. I'll include `number_of_dependents` and `number_of_referrals` here as numeric variables as well.

# %%
num_cols = card[card['nunique'] >= 10].index.to_list()

# %%
fig, axes = plt.subplots(len(num_cols), 2, figsize=(12, len(num_cols) * 3))

for i, col in enumerate(num_cols):
    sns.histplot(data=telco, x=col, ax=axes[i, 0], kde=True)
    axes[i, 0].set_title(f"Distribution of {col}")
    axes[i, 0].set_xlabel('')

    sns.boxplot(data=telco, x='churn_value', y=col, ax=axes[i, 1])
    axes[i, 1].set_title(f"{col} by churn")
    axes[i, 1].set_xlabel('')
    axes[i, 1].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Some observations:
#
# - `tenure_in_months` stands out; people who have been with the company for less seem more likely to churn
#
# - People with a higher `monthly_charge` seem slightly more likely to churn, however people with a smaller `total_revenue` or `total_long_distance_charges` seem more likely to churn

# %% [markdown]
# ## 6. Transforming skewed features
#
# In this section I'll apply log-transform to the two numerical features that stand out as right-skewed in the plots above: `total_long_distance_charges` and `total_revenue`.

# %%
for col in ['total_long_distance_charges', 'total_revenue']:
    telco[f"log_{col}"] = np.log1p(telco[col])

telco.drop(['total_long_distance_charges', 'total_revenue'], axis=1, inplace=True)

# %%
transformed = ['log_total_long_distance_charges', 'log_total_revenue']

fig, axes = plt.subplots(2, 2, figsize=(12, 6))

for i, col in enumerate(transformed):
    sns.histplot(data=telco, x=col, ax=axes[i, 0], kde=True)
    axes[i, 0].set_title(f"Distribution of {col}")
    axes[i, 0].set_xlabel('')

    sns.boxplot(data=telco, x='churn_value', y=col, ax=axes[i, 1])
    axes[i, 1].set_title(f"{col} by churn")
    axes[i, 1].set_xlabel('')
    axes[i, 1].set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Outliers

# %%
card = cardinality(telco)
card[card['nunique'] >= 10]
# Out:
#                                    nunique    dtype  \
# number_of_dependents                    10    int64
# number_of_referrals                     12    int64
# total_extra_data_charges                16    int64
# avg_monthly_gb_download                 50    int64
# age                                     62    int64
# tenure_in_months                        72    int64
# total_refunds                          500  float64
# monthly_charge                        1585  float64
# cltv                                  3438    int64
# avg_monthly_long_distance_charges     3584  float64
# log_total_long_distance_charges       6072  float64
# log_total_revenue                     6976  float64
#
#                                                                        unique_values
# number_of_dependents                                           [0, 3, 1 ...(cont'd)]
# number_of_referrals                                            [2, 0, 1 ...(cont'd)]
# total_extra_data_charges                                     [0, 10, 20 ...(cont'd)]
# avg_monthly_gb_download                                     [16, 10, 30 ...(cont'd)]
# age                                                         [37, 46, 50 ...(cont'd)]
# tenure_in_months                                              [9, 4, 13 ...(cont'd)]
# total_refunds                                        [0.0, 38.33, 21.25 ...(cont'd)]
# monthly_charge                                        [65.6, 59.9, 73.9 ...(cont'd)]
# cltv                                                  [2205, 5414, 4479 ...(cont'd)]
# avg_monthly_long_distance_charges                  [42.39, 10.69, 33.65 ...(cont'd)]
# log_total_long_distance_charges    [5.946754796715697, 4.576873586832978, 4.90970...
# log_total_revenue                  [6.883267895330866, 6.415555119339311, 6.03176...

# %%
num_cols = card[card['nunique'] >= 10].index

def identify_outliers(col, df=telco):
    """Returns the outliers list and their cardinality"""
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bd = q1 - 1.5 * iqr
    upper_bd = q3 + 1.5 * iqr

    outliers = df[(df[col] < lower_bd) | (df[col] > upper_bd)][col]

    return len(outliers), list(outliers)

# Plot outliers using box plots
fig, axes = plt.subplots(len(num_cols), 1, figsize=(12, len(num_cols) * 3))

for i, col in enumerate(num_cols):
    sns.boxplot(data=telco, x=col, ax=axes[i])
    axes[i].set_title(f"Number of outliers in {col}: {identify_outliers(col)[0]}")
    axes[i].set_ylabel('')
    axes[i].set_xlabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Most of these columns have outliers but they are not non-sensical and the data points seem informative, so I won't modify anything at this stage.

# %% [markdown]
# ## 8. Exporting dataset & concluding remarks
#
# In this notebook, I have examined and transformed the dataset features thoroughly and prepared it for the next prepocessing and modeling pipelines.
#
# More explicitly, I have:
#
# - replaced missing vales with appropriate ones based on the feature
#
# - removed several features that had repeated info, kept data as granular as possible
#
# - chosen to remove location related features too focus on a simpler churn model
#
# - removed features with no variance and id values as they are not useful for this analysis
#
# - handled several target related features to avoid data leakage
#
# - encoded binary variables manually to have positive values correspond to 1s to ensure consistent interpretability
#
# - inspected correlations, removed several features and created a new feature to avoid collinearity
#
# - explored data distributions, wrote down conclusions from visual analysis, removed a feature after noticing data leakage
#
# - applied log-transform to two right-skewed features
#
# - inspected outliers

# %%
print(f"Shape: {telco.shape}")
telco.head()
# Out:
# Shape: (7043, 29)
#              gender  age  married  number_of_dependents  number_of_referrals  \
# customer_id
# 0002-ORFBO   Female   37        1                     0                    2
# 0003-MKNFE     Male   46        0                     0                    0
# 0004-TLHLJ     Male   50        0                     0                    0
# 0011-IGKFF     Male   78        1                     0                    1
# 0013-EXCHZ   Female   75        1                     0                    3
#
#              tenure_in_months     offer  phone_service  \
# customer_id
# 0002-ORFBO                  9  no_offer              1
# 0003-MKNFE                  9  no_offer              1
# 0004-TLHLJ                  4   Offer E              1
# 0011-IGKFF                 13   Offer D              1
# 0013-EXCHZ                  3  no_offer              1
#
#              avg_monthly_long_distance_charges  multiple_lines internet_type  \
# customer_id
# 0002-ORFBO                               42.39               0         Cable
# 0003-MKNFE                               10.69               1         Cable
# 0004-TLHLJ                               33.65               0   Fiber Optic
# 0011-IGKFF                               27.82               0   Fiber Optic
# 0013-EXCHZ                                7.38               0   Fiber Optic
#
#              avg_monthly_gb_download  online_security  online_backup  \
# customer_id
# 0002-ORFBO                        16                0              1
# 0003-MKNFE                        10                0              0
# 0004-TLHLJ                        30                0              0
# 0011-IGKFF                         4                0              1
# 0013-EXCHZ                        11                0              0
#
#              device_protection_plan  premium_tech_support  streaming_tv  \
# customer_id
# 0002-ORFBO                        0                     1             1
# 0003-MKNFE                        0                     0             0
# 0004-TLHLJ                        1                     0             0
# 0011-IGKFF                        1                     0             1
# 0013-EXCHZ                        0                     1             1
#
#              unlimited_data        contract  paperless_billing  \
# customer_id
# 0002-ORFBO                1        One Year                  1
# 0003-MKNFE                0  Month-to-Month                  0
# 0004-TLHLJ                1  Month-to-Month                  1
# 0011-IGKFF                1  Month-to-Month                  1
# 0013-EXCHZ                1  Month-to-Month                  1
#
#               payment_method  monthly_charge  total_refunds  \
# customer_id
# 0002-ORFBO       Credit Card            65.6           0.00
# 0003-MKNFE       Credit Card            59.9          38.33
# 0004-TLHLJ   Bank Withdrawal            73.9           0.00
# 0011-IGKFF   Bank Withdrawal            98.0           0.00
# 0013-EXCHZ       Credit Card            83.9           0.00
#
#              total_extra_data_charges  churn_value  cltv  streaming  \
# customer_id
# 0002-ORFBO                          0            0  2205          0
# 0003-MKNFE                         10            0  5414          1
# 0004-TLHLJ                          0            1  4479          0
# 0011-IGKFF                          0            1  3714          0
# 0013-EXCHZ                          0            1  3464          0
#
#              log_total_long_distance_charges  log_total_revenue
# customer_id
# 0002-ORFBO                          5.946755           6.883268
# 0003-MKNFE                          4.576874           6.415555
# 0004-TLHLJ                          4.909709           6.031766
# 0011-IGKFF                          5.893466           7.378078
# 0013-EXCHZ                          3.141563           5.671741

# %%
cardinality(telco)
# Out:
#                                    nunique    dtype  \
# gender                                   2   object
# streaming                                2    int64
# churn_value                              2    int64
# paperless_billing                        2    int64
# unlimited_data                           2    int64
# streaming_tv                             2    int64
# premium_tech_support                     2    int64
# online_backup                            2    int64
# online_security                          2    int64
# device_protection_plan                   2    int64
# married                                  2    int64
# phone_service                            2    int64
# multiple_lines                           2    int64
# payment_method                           3   object
# contract                                 3   object
# internet_type                            4   object
# offer                                    6   object
# number_of_dependents                    10    int64
# number_of_referrals                     12    int64
# total_extra_data_charges                16    int64
# avg_monthly_gb_download                 50    int64
# age                                     62    int64
# tenure_in_months                        72    int64
# total_refunds                          500  float64
# monthly_charge                        1585  float64
# cltv                                  3438    int64
# avg_monthly_long_distance_charges     3584  float64
# log_total_long_distance_charges       6072  float64
# log_total_revenue                     6976  float64
#
#                                                                        unique_values
# gender                                                                [Female, Male]
# streaming                                                                     [0, 1]
# churn_value                                                                   [0, 1]
# paperless_billing                                                             [1, 0]
# unlimited_data                                                                [1, 0]
# streaming_tv                                                                  [1, 0]
# premium_tech_support                                                          [1, 0]
# online_backup                                                                 [1, 0]
# online_security                                                               [0, 1]
# device_protection_plan                                                        [0, 1]
# married                                                                       [1, 0]
# phone_service                                                                 [1, 0]
# multiple_lines                                                                [0, 1]
# payment_method                          [Credit Card, Bank Withdrawal, Mailed Check]
# contract                                        [One Year, Month-to-Month, Two Year]
# internet_type                                  [Cable, Fiber Optic, DSL ...(cont'd)]
# offer                                       [no_offer, Offer E, Offer D ...(cont'd)]
# number_of_dependents                                           [0, 3, 1 ...(cont'd)]
# number_of_referrals                                            [2, 0, 1 ...(cont'd)]
# total_extra_data_charges                                     [0, 10, 20 ...(cont'd)]
# avg_monthly_gb_download                                     [16, 10, 30 ...(cont'd)]
# age                                                         [37, 46, 50 ...(cont'd)]
# tenure_in_months                                              [9, 4, 13 ...(cont'd)]
# total_refunds                                        [0.0, 38.33, 21.25 ...(cont'd)]
# monthly_charge                                        [65.6, 59.9, 73.9 ...(cont'd)]
# cltv                                                  [2205, 5414, 4479 ...(cont'd)]
# avg_monthly_long_distance_charges                  [42.39, 10.69, 33.65 ...(cont'd)]
# log_total_long_distance_charges    [5.946754796715697, 4.576873586832978, 4.90970...
# log_total_revenue                  [6.883267895330866, 6.415555119339311, 6.03176...

# %%
telco.to_csv("../data/processed/telco_cleaned.csv")

# %% [markdown]
# In the next notebook, I will create pipelines that include the next prepocessing steps such as separating the dataset into training and test sets, scaling and one-hot encoding. Comparing models will follow including logistic regression, random forest classifier and xgboost.
#
# Remarks:
#
# - I have kept data more granular than binary whenever I could, but it's worthwhile to experiment with simpler binary encodings to see which performs better. Relevant features include `internet_type`, `number_of_dependents`, `number_of_referrals`, `offer`, `age`.
#
# - It is worthwhile to experiment with customizing `tenure_in_months` as it is highly correlated with churn and also with `total_revenue`. I could try binning into groups or consider `total_revenue`/`tenure_in_months`.
#
# - I haven't examined relationships between categorical variables yet, I need to add this correlation analysis to this notebook.
